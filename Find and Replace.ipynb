# %%
import pandas as pd

import numpy as np

# %%
GA_views = pd.read_excel('../Google Analytics/Google_Analytics_Views.xlsx')

GA_views
# Out:
#         Unnamed: 0                                               Page  \
# 0                0  community.rws.com/product-groups/trados-portfo...
# 1                1  community.rws.com/product-groups/trados-portfo...
# 2                2  community.rws.com/product-groups/trados-portfo...
# 3                3  community.rws.com/product-groups/trados-portfo...
# 4                4  community.rws.com/product-groups/trados-portfo...
# ...            ...                                                ...
# 110831      110831  community.rws.com/tags/Passolo+2018/Trados+Studio
# 110832      110832      community.rws.com/tags/Tridion+Success+Summit
# 110833      110833                     community.rws.com/tags/Webinar
# 110834      110834                 community.rws.com/utility/editpage
# 110835      110835                         community.rws.com/webinars
#
#         Pageviews  Unique Pageviews  Avg. Time on Page  Entrances  \
# ...

# %%
GA_views.drop(['Unnamed: 0'], inplace=True, axis=1)

GA_views.head()
# Out:
#                                                 Page  Pageviews  \
# 0  community.rws.com/product-groups/trados-portfo...          3
# 1  community.rws.com/product-groups/trados-portfo...          3
# 2  community.rws.com/product-groups/trados-portfo...          3
# 3  community.rws.com/product-groups/trados-portfo...          3
# 4  community.rws.com/product-groups/trados-portfo...          3
#
#    Unique Pageviews  Avg. Time on Page  Entrances  Bounce Rate  % Exit  \
# 0                 2         147.333333          0          0.0     0.0
# 1                 3          23.666667          0          0.0     0.0
# 2                 3          16.000000          0          0.0     0.0
# 3                 2          15.000000          1          0.0     0.0
# 4                 3          25.000000          0          0.0     0.0
#
#    Page Value        Product_Group month_year
# 0         0.0  Language Technology   Aug 2022
# 1         0.0  Language Technology   Aug 2022
# ...

# %%
GA_views.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110836 entries, 0 to 110835
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Page               110836 non-null  object
#  1   Pageviews          110836 non-null  int64
#  2   Unique Pageviews   110836 non-null  int64
#  3   Avg. Time on Page  110836 non-null  float64
#  4   Entrances          110836 non-null  int64
#  5   Bounce Rate        110836 non-null  float64
#  6   % Exit             110836 non-null  float64
#  7   Page Value         110836 non-null  float64
#  8   Product_Group      110836 non-null  object
#  9   month_year         110836 non-null  object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 8.5+ MB

# %%
GA_views['Product_Group'] = GA_views['Product_Group'].replace(['Artficial Intelligence'], 'Artificial Intelligence')

GA_views
# Out:
#                                                      Page  Pageviews  \
# 0       community.rws.com/product-groups/trados-portfo...          3
# 1       community.rws.com/product-groups/trados-portfo...          3
# 2       community.rws.com/product-groups/trados-portfo...          3
# 3       community.rws.com/product-groups/trados-portfo...          3
# 4       community.rws.com/product-groups/trados-portfo...          3
# ...                                                   ...        ...
# 110831  community.rws.com/tags/Passolo+2018/Trados+Studio          1
# 110832      community.rws.com/tags/Tridion+Success+Summit          1
# 110833                     community.rws.com/tags/Webinar          1
# 110834                 community.rws.com/utility/editpage          1
# 110835                         community.rws.com/webinars          1
#
#         Unique Pageviews  Avg. Time on Page  Entrances  Bounce Rate  % Exit  \
# ...

# %%
GA_views.loc[GA_views['Product_Group'] == 'Artificial Intelligence']
# Out:
#                                                      Page  Pageviews  \
# 1523    community.rws.com/ideas/linguistic-ai-ideas/i/...          2
# 1524    community.rws.com/ideas/linguistic-ai-ideas/i/...          2
# 1525    community.rws.com/ideas/linguistic-ai-ideas/i/...          2
# 1721       community.rws.com/product-groups/linguistic-ai          2
# 1722    community.rws.com/product-groups/linguistic-ai...          2
# ...                                                   ...        ...
# 105364  community.rws.com/product-groups/linguistic-ai...          1
# 105365  community.rws.com/product-groups/linguistic-ai...          1
# 105366  community.rws.com/product-groups/linguistic-ai...          1
# 105367  community.rws.com/product-groups/linguistic-ai...          1
# 105368  community.rws.com/product-groups/linguistic-ai...          1
#
#         Unique Pageviews  Avg. Time on Page  Entrances  Bounce Rate  % Exit  \
# ...

# %%
GA_views
# Out:
#                                                      Page  Pageviews  \
# 0       community.rws.com/product-groups/trados-portfo...          3
# 1       community.rws.com/product-groups/trados-portfo...          3
# 2       community.rws.com/product-groups/trados-portfo...          3
# 3       community.rws.com/product-groups/trados-portfo...          3
# 4       community.rws.com/product-groups/trados-portfo...          3
# ...                                                   ...        ...
# 110831  community.rws.com/tags/Passolo+2018/Trados+Studio          1
# 110832      community.rws.com/tags/Tridion+Success+Summit          1
# 110833                     community.rws.com/tags/Webinar          1
# 110834                 community.rws.com/utility/editpage          1
# 110835                         community.rws.com/webinars          1
#
#         Unique Pageviews  Avg. Time on Page  Entrances  Bounce Rate  % Exit  \
# ...

# %%
writer = pd.ExcelWriter('Google_Analytics_Views_Updated_31_03_2023.xlsx',
                       engine='xlsxwriter',
                       engine_kwargs={'options': {'strings_to_urls':False}}
                       )
GA_views.to_excel(writer)

writer.close()
